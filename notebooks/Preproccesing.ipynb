# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\User\Desktop\Week_4\Amharic-E-commerce-Data-Extractor\data\telegram_data.csv')

# %%
df.head(20)
# Out:
#      Channel Title Channel Username    ID  \
# 0   Zemen Express®    @ZemenExpress  6982
# 1   Zemen Express®    @ZemenExpress  6981
# 2   Zemen Express®    @ZemenExpress  6980
# 3   Zemen Express®    @ZemenExpress  6979
# 4   Zemen Express®    @ZemenExpress  6978
# 5   Zemen Express®    @ZemenExpress  6977
# 6   Zemen Express®    @ZemenExpress  6976
# 7   Zemen Express®    @ZemenExpress  6975
# 8   Zemen Express®    @ZemenExpress  6974
# 9   Zemen Express®    @ZemenExpress  6973
# 10  Zemen Express®    @ZemenExpress  6972
# 11  Zemen Express®    @ZemenExpress  6971
# 12  Zemen Express®    @ZemenExpress  6970
# 13  Zemen Express®    @ZemenExpress  6969
# 14  Zemen Express®    @ZemenExpress  6968
# 15  Zemen Express®    @ZemenExpress  6967
# 16  Zemen Express®    @ZemenExpress  6966
# 17  Zemen Express®    @ZemenExpress  6965
# 18  Zemen Express®    @ZemenExpress  6964
# 19  Zemen Express®    @ZemenExpress  6963
#
#                                               Message  \
# ...

# %%
import pandas as pd

# Step 1: Load the existing CSV file (assumes it was saved in utf-8)
df = pd.read_csv(r'C:\Users\User\Desktop\Week_4\Amharic-E-commerce-Data-Extractor\data\telegram_data.csv', encoding='utf-8')
# Step 2: Save it again with UTF-8 with BOM (utf-8-sig)
df.to_csv(r'C:\Users\User\Desktop\Week_4\Amharic-E-commerce-Data-Extractor\data\telegram_data_utf8_fixed.csv', index=False, encoding='utf-8-sig')
